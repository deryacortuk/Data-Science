# %%
import seaborn as sns

# %%
data = sns.load_dataset("tips")
df = data.copy()

# %%
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
sns.boxplot(x="day",y="total_bill",data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(y="total_bill",kind="violin",data=df)

# %%
sns.catplot(x="day",y="total_bill",kind="violin",data=df)

# %%
sns.catplot(x="day",y="total_bill",hue="sex",kind="violin",data=df)

# %%
sns.scatterplot(x="total_bill",y="tip", data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip", hue="time",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip", hue="time",style="time",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip", hue="day",style="day",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x="total_bill",y="tip",size="size", hue="size",data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt

# %%
sns.lmplot(x="total_bill", y="tip",data=df)

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker",data=df)

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker", col="time",data=df)

# %%
sns.lmplot(x="total_bill", y="tip",hue="smoker", col="time",row="sex",data=df)

# %%
iris = sns.load_dataset("iris")
dfi = iris.copy()

# %%
dfi.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
dfi.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
dfi.shape
# Out:
# (150, 5)

# %%
sns.pairplot(dfi)

# %%
sns.pairplot(dfi, hue="species")

# %%
sns.pairplot(dfi, hue="species", markers=["o","s","D"])

# %%
sns.pairplot(dfi, hue="species",kind="reg")

# %%
fg = sns.load_dataset("flights")
dff = fg.copy()

# %%
dff.describe().T
# Out:
#             count         mean         std     min      25%     50%      75%  \
# year        144.0  1954.500000    3.464102  1949.0  1951.75  1954.5  1957.25
# passengers  144.0   280.298611  119.966317   104.0   180.00   265.5   360.50
#
#                max
# year        1960.0
# passengers   622.0

# %%
dff.dtypes
# Out:
# year             int64
# month         category
# passengers       int64
# dtype: object

# %%
dff.shape
# Out:
# (144, 3)

# %%
dff["passengers"].describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
dff = dff.pivot("month","year","passengers")
# Out:
# C:\Users\Derya\AppData\Local\Temp\ipykernel_30688\1255182540.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   dff = dff.pivot("month","year","passengers")

# %%
sns.heatmap(dff)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.heatmap(dff, annot=True, fmt ="d",linewidths=5,cbar=False)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
fm = sns.load_dataset("fmri")
dfm = fm.copy()

# %%
dfm.shape
# Out:
# (1064, 5)

# %%
dfm.describe().T
# Out:
#             count     mean       std       min      25%       50%        75%  \
# timepoint  1064.0  9.00000  5.479801  0.000000  4.00000  9.000000  14.000000
# signal     1064.0  0.00354  0.093930 -0.255486 -0.04607 -0.013653   0.024293
#
#                  max
# timepoint  18.000000
# signal      0.564985

# %%
dfm.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
dfm["timepoint"].describe()
# Out:
# count    1064.000000
# mean        9.000000
# std         5.479801
# min         0.000000
# 25%         4.000000
# 50%         9.000000
# 75%        14.000000
# max        18.000000
# Name: timepoint, dtype: float64

# %%
sns.lineplot(x="timepoint",y="signal",data=dfm)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",data=dfm)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",hue="event",style="event", markers=True, dashes=False,data=dfm)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint",y="signal",hue="region",style="event", markers=True, dashes=False,data=dfm)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
import pandas_datareader as pr
